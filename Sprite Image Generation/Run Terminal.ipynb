# %%
# !cd C:\Users\ipzac\Documents\Personal-Projects\Sprite Image Generation    
# %run main.py
# Out:
# Epoch 1; Elapsed time = 00:00:00s
# 273/273: G=6.572, E=0.617, Dx=0.050, Dz=0.711  Rx=0.335  Rz=0.398
# Epoch 2; Elapsed time = 00:02:41s
# 273/273: G=5.568, E=0.689, Dx=0.068, Dz=0.702  Rx=0.143  Rz=0.104
# Epoch 3; Elapsed time = 00:05:20s
# 273/273: G=5.040, E=0.702, Dx=0.106, Dz=0.698  Rx=0.134  Rz=0.085
# Epoch 4; Elapsed time = 00:08:01s
# 273/273: G=4.463, E=0.709, Dx=0.139, Dz=0.693  Rx=0.129  Rz=0.085
# Epoch 5; Elapsed time = 00:10:40s
# 273/273: G=3.910, E=0.711, Dx=0.173, Dz=0.690  Rx=0.123  Rz=0.080
# Epoch 6; Elapsed time = 00:13:19s
# 273/273: G=3.399, E=0.711, Dx=0.201, Dz=0.688  Rx=0.121  Rz=0.078
# Epoch 7; Elapsed time = 00:15:57s
# 273/273: G=2.981, E=0.705, Dx=0.239, Dz=0.690  Rx=0.121  Rz=0.077
# Epoch 8; Elapsed time = 00:18:36s
# 273/273: G=2.671, E=0.701, Dx=0.252, Dz=0.691  Rx=0.119  Rz=0.073
# Epoch 9; Elapsed time = 00:21:15s
# 273/273: G=2.594, E=0.697, Dx=0.270, Dz=0.692  Rx=0.119  Rz=0.071
# Epoch 10; Elapsed time = 00:23:53s
# ...
